# %% [markdown]
# # Conditions and Branching

# %% [markdown]
# # Comparison Operators

# %%
# Condition Equal

a = 8
a == 6
# Out:
# False

# %%
# Greater than Sign

i = 6
i > 5
# Out:
# True

# %%
# Inequality Sign

i = 2
i != 6
# Out:
# True

# %%
# Use Equality sign to compare the strings

"ACDC" == "Michael Jackson"
# Out:
# False

# %% [markdown]
# # Branching

# %%
# If statement example

age = 25

if age > 24:
        print("you can enter" )
# Out:
# you can enter

# %%
#Condition and Branching

a = 15
if(a == 7):
    print("True")
else:
    print("False")
# Out:
# False

# %%
a = 15
if(a == 8):
    print("Answer is 8")
elif(a == 15):
    print("Answer is 15")
else:
    print("Answer does not found")
# Out:
# Answer is 15

# %%
a = 115
if(a == 8):
    print("Answer is 8")
elif(a == 15):
    print("Answer is 15")
elif(a == 115):
    print("Answer is 115")    
else:
    print("Answer does not found")
# Out:
# Answer is 115
