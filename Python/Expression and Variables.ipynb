# %% [markdown]
# # Type Of Data

# %%
a=10
float(a)
# Out:
# 10.0

# %%
type(a)
# Out:
# int

# %%
b=10.0
int(b)
# Out:
# 10

# %%
type(b)
# Out:
# float

# %% [markdown]
# str(1)
# str(2.00)

# %%
str(2.00)
# Out:
# '2.0'

# %%
str(1)
# Out:
# '1'

# %% [markdown]
# # part 1 of lab (Expression and Variables)

# %%
# Try your first Python output

print('Hello, Python!')
# Out:
# Hello, Python!

# %%
import sys
print(sys.version)
# Out:
# 3.8.5 (default, Sep  3 2020, 21:29:08) [MSC v.1916 64 bit (AMD64)]

# %%
# Practice on writing comments

print('Hello, Python!') # This line prints a string
# print('Hi')
# Out:
# Hello, Python!

# %%
# Print string as error message

frint("Hello, Python!")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-313a1769a8a5> in <module>
#       1 # Print string as error message
#       2
# ----> 3 frint("Hello, Python!")
#
# NameError: name 'frint' is not defined

# %%
# Try to see build in error message

print("Hello, Python!)
# Out:
#   File "<ipython-input-17-63a21a726720>", line 3
#     print("Hello, Python!)
#                           ^
# SyntaxError: EOL while scanning string literal

# %%
# Print string and error to see the running order

print("This will be printed")
frint("This will cause an error")
print("This will NOT be printed")
# Out:
# This will be printed
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-af59af1b345d> in <module>
#       2
#       3 print("This will be printed")
# ----> 4 frint("This will cause an error")
#       5 print("This will NOT be printed")
#
# NameError: name 'frint' is not defined

# %%
# Write your code below. Don't forget to press Shift+Enter to execute the cell
print('Hello, World!')
# Out:
# Hello, World!

# %% [markdown]
# # Types Of Object In The Python

# %%
# Integer

11

# %%
#Float

2.00

# %%
#String 

"Hello, Python 101!"

# %%
# Type of 11

type(11)
# Out:
# int

# %%
# Type of 2.00

type(2.00)
# Out:
# float

# %%
# Type of "Hello, Python 101!"

type("Hello, Python 101!")
# Out:
# str

# %%
# Some Example Of The Integer

# %%
# Print the type of -1

type(-1)
# Out:
# int

# %%
# Print the type of 4

type(4)
# Out:
# int

# %%
# Print the type of 0

type(0)
# Out:
# int

# %%
# Some Example Of The Float

# %%
# Print the type of 1.0

type(1.0) # Notice that 1 is an int, and 1.0 is a float
# Out:
# float

# %%
# Print the type of 0.5

type(0.5)
# Out:
# float

# %%
# Print the type of 0.56

type(0.56)
# Out:
# float

# %%
# System settings about float type
import sys
sys.float_info
# Out:
# sys.float_info(max=1.7976931348623157e+308, max_exp=1024, max_10_exp=308, min=2.2250738585072014e-308, min_exp=-1021, min_10_exp=-307, dig=15, mant_dig=53, epsilon=2.220446049250313e-16, radix=2, rounds=1)

# %% [markdown]
# # Converting To One Type To Different Type Of Object

# %%
# Verify that this is an integer

type(2)
# Out:
# int

# %%
# Convert 2 to a float

float(2)
# Out:
# 2.0

# %%
# Convert integer 2 to a float and check its type

type(float(2))
# Out:
# float

# %%
# Casting 1.1 to integer will result in loss of information

int(1.1)
type(int(1.1))
# Out:
# int

# %%
# Convert a string into an integer

int('1')
# Out:
# 1

# %%
# Convert a string into an integer with error

int('12 ')
# Out:
# 12

# %%
# Convert the string "1.2" into a float

float('1.2')
type(float('1.2'))
# Out:
# float

# %%
# Convert an integer to a string
a=1
a=str(1)
type(a)
# Out:
# str

# %%
# Convert a float to a string

str(1.2)
# Out:
# '1.2'

# %%
# Type of True

type(True)
# Out:
# bool

# %%
# Type of False

type(False)
# Out:
# bool

# %%
# Convert 1 to boolean

bool(1)
# Out:
# True

# %%
# Convert 0 to boolean

bool(0)
# Out:
# False

# %%
# Convert True to float

float(True)
# Out:
# 1.0

# %%
# Write your code below. Don't forget to press Shift+Enter to execute the cell
type(6/2)
# Out:
# float

# %%
# Write your code below. Don't forget to press Shift+Enter to execute the cell
type(6//2)
# Out:
# int

# %%
# Addition operation expression

43 + 60 + 16 + 41
# Out:
# 160

# %%
# Subtraction operation expression

50 - 60
# Out:
# -10

# %%
# Division operation expression

25 / 5
# Out:
# 5.0

# %%
# Division operation expression

25 / 6
# Out:
# 4.166666666666667

# %%
# Integer division operation expression


25 // 5
# Out:
# 5

# %%
# Integer division operation expression

25 // 6
# Out:
# 4

# %%
# Mathematical expression

(30 + 2) * 60
# Out:
# 1920

# %%
# Store value into variable
x = 43 + 60 + 16 + 41
x
# Out:
# 160

# %%
# Complicate expression

total_hours = (43 + 42 + 57) / 60  # Total hours in a single expression
total_hours
# Out:
# 2.3666666666666667
